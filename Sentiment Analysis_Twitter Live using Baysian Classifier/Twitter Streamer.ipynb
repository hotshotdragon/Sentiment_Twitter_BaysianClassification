# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
#import MySQLdb
#import time
import json
import sentiment_mod as s


#        replace mysql.server with "localhost" if you are running via your own server!
#                        server       MySQL username	MySQL pass  Database name.
#conn = MySQLdb.connect("mysql.server","beginneraccount","cookies","beginneraccount$tutorial")

#c = conn.cursor()


#consumer key, consumer secret, access token, access secret.
ckey="############"
csecret="################"
atoken="############"
asecret="#########"

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)

        tweet = all_data["text"]
        sentiment_value,confidence = s.sentiment(tweet)
        print(tweet, sentiment_value, confidence)
        if confidence*100 >= 80:
            output = open("twitter-out.txt","a")
            output.write(sentiment_value)
            output.write('\n')
            output.close()
 
        return True

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["flipkart"])
# Out:
# RT @suvojitc: Walmart bought Flipkart. Flipkart bought Walmart India. So Walmart bought Walmart India? Why? neg 1.0
# Flipkart buys Walmart India Business to launch Flipkart Wholesale in India https://t.co/boa9nSMqge neg 1.0
# @ndcnn @businessline You cannot take #vocalforlocal more seriously! Everyone is talking about strengthening the eco… https://t.co/jRl6dA1CxN neg 1.0
# @philipsindia @Philips Hi Team,
# I order one of your product induction but it’s not working properly as heating by w… https://t.co/6mADgC6hXW pos 1.0
# Flipkart buys parent Walmart's Indian wholesale business neg 1.0
# RT @muglikar_: Flipkart group to launch Flipkart wholesale. Big step towards #AtmaNirbharBharat.This will help our Kiranas &amp; local stores c… pos 0.6
# RT @htTweets: Flipkart acquires Walmart India, to launch Flipkart Wholesale in Aug
#
# https://t.co/hSBYs1Jsfe https://t.co/1hwWX752bg neg 1.0
# Our revolutionary #LivinguardFaceMasks are now available for purchase on @Flipkart.
# Buy Now:… https://t.co/zXweNEbAqk pos 1.0
# Flipkart ने Walmart India Business को Acquire करके Wholesale Marketplace को लांच किया https://t.co/OlSsIrkW4H neg 1.0
# Flipkart group acquires Walmart India, to launch of wholesale marketplace https://t.co/vQQzZXiBOx via @timesofindia neg 1.0
# @Flipkart Ordered 48 pieces of diaper pants for my baby. Received only 24 pieces that too with no Flipkart packagin… https://t.co/3gAhkKwk6M neg 1.0
# RT @dev_dharani: First Walmart bought Flipkart, now Flipkart bough Walmart India..
#
# Flipkart wholesale be like: https://t.co/ay0o8FwUl3 neg 1.0
# RT @TransparentCap3: Flipkart said its wholesale unit will acquire Walmart India’s cash-and-carry business that owns the Best Price brand,… pos 1.0
# Honor 9S to Launch in India on July 31, Flipkart Availability Confirmed https://t.co/ghM1u7K6TQ neg 1.0
# Honor 9S to Launch in India on July 31, Flipkart Availability Confirmed https://t.co/1MHvHrbEiQ neg 1.0
# RT @BiIndia: #Flipkart has acquired #WalmartIndia’s business and has announced the launch of Flipkart Wholesale.
#
# https://t.co/k93aS8B4mM h… pos 1.0
# Flipkart Acquires Walmart India, to Launch Flipkart Wholesale for B2B Segment in August https://t.co/AvgVIo5Gt2 neg 1.0
# Our revolutionary #LivinguardFaceMasks are now available for purchase on Flipkart.
# Buy Now:… https://t.co/y0DfIZpZtC pos 1.0
# E-commerce company, #Flipkart, has acquired 100% stake in #WalmartIndia and has launched Flipkart Wholesale, a new… https://t.co/cHsxsYwgld pos 1.0
# RT @aajtak: फ्लिपकार्ट ने वॉलमार्ट इंडिया की 100 फीसदी हिस्सेदारी खरीद ली है
# https://t.co/DLoAoCt9ru neg 1.0
# @ndcnn @businessline Can we expect this from any other brand? No! Only a made in India brand can take such steps to… https://t.co/N1Yv5VYdij neg 1.0
# Flipkart Offer: Buy Men Lungis Under Rs.249 https://t.co/8fWW7z3dKH
#
# #Deals #Offers #Bestdeals #Bestoffers… https://t.co/FOIHQScLsW neg 1.0
# @EdSohel @cmanmohan @Flipkart Poco phones are being assembled in Andhra Pradesh (our state) but The mobiles are bei… https://t.co/g7WqevXpBF neg 1.0
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# E:\Softwares\Anaconda\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# E:\Softwares\Anaconda\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# E:\Softwares\Anaconda\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-be7780dee7ed> in <module>
#      44
#      45 twitterStream = Stream(auth, listener())
# ---> 46 twitterStream.filter(track=["flipkart"])
#
# E:\Softwares\Anaconda\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# E:\Softwares\Anaconda\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# E:\Softwares\Anaconda\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# E:\Softwares\Anaconda\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# E:\Softwares\Anaconda\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# E:\Softwares\Anaconda\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# E:\Softwares\Anaconda\lib\http\client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# E:\Softwares\Anaconda\lib\http\client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# E:\Softwares\Anaconda\lib\http\client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# E:\Softwares\Anaconda\lib\http\client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# E:\Softwares\Anaconda\lib\http\client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# E:\Softwares\Anaconda\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# E:\Softwares\Anaconda\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# E:\Softwares\Anaconda\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# E:\Softwares\Anaconda\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      81     # thing.)
#      82     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 83     rready, wready, xready = _retry_on_intr(fn, timeout)
#      84     return bool(rready or wready or xready)
#      85
#
# E:\Softwares\Anaconda\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# KeyboardInterrupt:
